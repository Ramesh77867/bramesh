# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (4.6.3)

# %%
pip install google
# Out:
# Requirement already satisfied: google in /usr/local/lib/python3.6/dist-packages (2.0.3)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.6/dist-packages (from google) (4.6.3)

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "prime minister lists in india"
  
for j in search(query, tld="co.in", num=10, stop=10, pause=2): 
    print(j)
# Out:
# https://en.wikipedia.org/wiki/List_of_prime_ministers_of_India
# https://simple.wikipedia.org/wiki/List_of_Prime_Ministers_of_India
# https://www.britannica.com/topic/list-of-prime-ministers-of-India-1832692
# https://www.jagranjosh.com/general-knowledge/list-of-all-prime-ministers-of-india-1473165149-1
# https://www.oneindia.com/elections/prime-ministers-of-india/
# https://knowindia.gov.in/general-information/prime-ministers-of-india.php
# https://www.wikiwand.com/en/List_of_prime_ministers_of_India
# https://www.careerpower.in/list-of-prime-minister-of-india.html
# https://pop-culture.fandom.com/wiki/List_of_Prime_Ministers_of_India
# https://byjus.com/govt-exams/list-of-indian-prime-ministers/

# %%
try: 
    from googlesearch import search 
except ImportError:  
    print("No module named 'google' found") 
  
# to search 
query = "https://in.pinterest.com/pin/624874517021903697/"
  
for j in search(query, tld="co.in", num=10, stop=10, pause=2): 
    print(j)
# Out:
# https://in.pinterest.com/pin/624874517021903697/
# https://in.pinterest.com/pin/645703665312879327/?amp_client_id=CLIENT_ID(_)&mweb_unauth_id=%7B%7Bdefault.session%7D%7D&amp_url=https%3A%2F%2Fin.pinterest.com%2Famp%2Fpin%2F624874517021903697%2F
# https://in.pinterest.com/pin/343892121541895109/?amp_client_id=CLIENT_ID(_)&mweb_unauth_id=%7B%7Bdefault.session%7D%7D&amp_url=https%3A%2F%2Fin.pinterest.com%2Famp%2Fpin%2F624874517021903697%2F
# https://in.pinterest.com/pin/689965605400220363/?amp_client_id=CLIENT_ID(_)&mweb_unauth_id=%7B%7Bdefault.session%7D%7D&amp_url=https%3A%2F%2Fin.pinterest.com%2Famp%2Fpin%2F624874517021903697%2F
# https://in.pinterest.com/pin/565694403201634407/?amp_client_id=CLIENT_ID(_)&mweb_unauth_id=%7B%7Bdefault.session%7D%7D&amp_url=https%3A%2F%2Fin.pinterest.com%2Famp%2Fpin%2F624874517021903697%2F
# https://in.pinterest.com/pin/843862048917311598/?amp_client_id=CLIENT_ID(_)&mweb_unauth_id=%7B%7Bdefault.session%7D%7D&amp_url=https%3A%2F%2Fin.pinterest.com%2Famp%2Fpin%2F624874517021903697%2F
# https://in.pinterest.com/pin/750693831622540689/?amp_client_id=CLIENT_ID(_)&mweb_unauth_id=%7B%7Bdefault.session%7D%7D&amp_url=https%3A%2F%2Fin.pinterest.com%2Famp%2Fpin%2F624874517021903697%2F
# https://www.pinterest.at/pin/624874517021903697/?amp_client_id=CLIENT_ID(_)&mweb_unauth_id=&simplified=true
